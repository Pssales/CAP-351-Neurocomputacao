# %%
import sys
sys.path.insert(0, '../')

# %%
from minisom import MiniSom

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline

# %load_ext autoreload

# %%
# %autoreload 2
data = np.genfromtxt('iris.csv', delimiter=',', usecols=(0, 1, 2, 3))
# data normalization
data = np.apply_along_axis(lambda x: x/np.linalg.norm(x), 1, data)

# Initialization and training
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)

som.pca_weights_init(data)
print("Training...")
som.train_batch(data, 1000, verbose=True)  # random training
print("\n...ready!")

plt.figure(figsize=(7, 7))
# Plotting the response for each pattern in the iris dataset
plt.pcolor(som.distance_map().T, cmap='bone_r')  # plotting the distance map as background
#plt.colorbar()

target = np.genfromtxt('iris.csv', delimiter=',', usecols=(4), dtype=str)
t = np.zeros(len(target), dtype=int)
t[target == 'setosa'] = 0
t[target == 'versicolor'] = 1
t[target == 'virginica'] = 2

# use different colors and markers for each label
markers = ['o', 's', 'D']
colors = ['C0', 'C1', 'C2']
for cnt, xx in enumerate(data):
    w = som.winner(xx)  # getting the winner
    # palce a marker on the winning position for the sample xx
    plt.plot(w[0]+.5, w[1]+.5, markers[t[cnt]], markerfacecolor='None',
             markeredgecolor=colors[t[cnt]], markersize=12, markeredgewidth=2)
plt.axis([0, 7, 0, 7])
plt.savefig('som_iris.png')
plt.show()
# Out:
# Training...
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 7.347051631709537e-05
#  topographic error: 0.13333333333333333
#
# ...ready!

# %% [markdown]
# Activations frequencies
# ----

# %%
plt.figure(figsize=(8, 7))
frequencies = som.activation_response(data)
plt.pcolor(frequencies.T, cmap='Blues') 
plt.colorbar()
plt.show()

# %% [markdown]
# Class pies
# ----

# %%
label = np.genfromtxt('iris.csv', delimiter=',', usecols=(4), dtype=str)
labels_map = som.labels_map(data, label)
label_names = np.unique(label)

plt.figure(figsize=(7, 7))
the_grid = GridSpec(7, 7)
for position in labels_map.keys():
    label_fracs = [labels_map[position][l] for l in label_names]
    plt.subplot(the_grid[6-position[1], position[0]], aspect=1)
    patches, texts = plt.pie(label_fracs)
plt.legend(patches, label_names, bbox_to_anchor=(0, 1.5), ncol=3)
plt.savefig('som_iris_pies.png')
plt.show()

# %% [markdown]
# Quantization error
# ----

# %%
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)
som.pca_weights_init(data)
max_iter = 10000
q_error = []
t_error = []
iter_x = []
for i in range(max_iter):
    percent = 100*(i+1)/max_iter
    rand_i = np.random.randint(len(data)) # This corresponds to train_random() method.
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
    if (i+1) % 100 == 0:
        q_error.append(som.quantization_error(data))
        t_error.append(som.topographic_error(data))
        iter_x.append(i)
        sys.stdout.write(f'\riteration={i:2d} status={percent:0.2f}%')
        
plt.plot(iter_x, q_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# iteration=9999 status=100.00%
# Text(0.5, 0, 'iteration index')

# %%
plt.plot(iter_x, t_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# Text(0.5, 0, 'iteration index')

# %% [markdown]
# Datase 2

# %%
data = np.genfromtxt( "../data/balance-scale.data", delimiter="," , usecols=( 1, 2, 3,4));
# data normalization
data = np.apply_along_axis(lambda x: x/np.linalg.norm(x), 1, data)

# %%
# Initialization and training
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)

som.pca_weights_init(data)
print("Training...")
som.train_batch(data, 1000, verbose=True)  # random training
print("\n...ready!")

plt.figure(figsize=(7, 7))
# Plotting the response for each pattern in the iris dataset
plt.pcolor(som.distance_map().T, cmap='bone_r')  # plotting the distance map as background
#plt.colorbar()

target = np.genfromtxt('../data/balance-scale.data', delimiter=',', usecols=(0))
t = np.zeros(len(target), dtype=int)

# use different colors and markers for each label
markers = ['o', 's', 'D','<','>']
colors = ['C0', 'C1', 'C2','C3', 'C4']
for cnt, xx in enumerate(data):
    w = som.winner(xx)  # getting the winner
    # palce a marker on the winning position for the sample xx
    plt.plot(w[0]+.5, w[1]+.5, markers[t[cnt]], markerfacecolor='None',
             markeredgecolor=colors[t[cnt]], markersize=12, markeredgewidth=2)
plt.axis([0, 7, 0, 7])
plt.savefig('som_iris.png')
plt.show()
# Out:
# Training...
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.005116924235446196
#  topographic error: 0.256
#
# ...ready!

# %% [markdown]
# Activations frequencies
# ----

# %%
plt.figure(figsize=(8, 7))
frequencies = som.activation_response(data)
plt.pcolor(frequencies.T, cmap='Blues') 
plt.colorbar()
plt.show()

# %% [markdown]
# Class pies
# ----

# %%
label = np.genfromtxt('../data/balance-scale.data', delimiter=',', usecols=(1), dtype=str)
labels_map = som.labels_map(data, label)
label_names = np.unique(label)

plt.figure(figsize=(7, 7))
the_grid = GridSpec(7, 7)
for position in labels_map.keys():
    label_fracs = [labels_map[position][l] for l in label_names]
    plt.subplot(the_grid[6-position[1], position[0]], aspect=1)
    patches, texts = plt.pie(label_fracs)
plt.legend(patches, label_names, bbox_to_anchor=(0, 1.5), ncol=3)
plt.savefig('som_iris_pies.png')
plt.show()

# %% [markdown]
# Quantization error
# ----

# %%
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)
som.pca_weights_init(data)
max_iter = 10000
q_error = []
t_error = []
iter_x = []
for i in range(max_iter):
    percent = 100*(i+1)/max_iter
    rand_i = np.random.randint(len(data)) # This corresponds to train_random() method.
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
    if (i+1) % 100 == 0:
        q_error.append(som.quantization_error(data))
        t_error.append(som.topographic_error(data))
        iter_x.append(i)
        sys.stdout.write(f'\riteration={i:2d} status={percent:0.2f}%')
        
plt.plot(iter_x, q_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# iteration=9999 status=100.00%
# Text(0.5, 0, 'iteration index')

# %%
plt.plot(iter_x, t_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# Text(0.5, 0, 'iteration index')

# %% [markdown]
# ## Dataset 3

# %%
data = np.genfromtxt( "../data/transfusion.csv", delimiter="," , usecols=(0,1,2,3));
# data normalization
data = np.apply_along_axis(lambda x: x/np.linalg.norm(x), 1, data)

# %%
# Initialization and training
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)

som.pca_weights_init(data)
print("Training...")
som.train_batch(data, 1000, verbose=True)  # random training
print("\n...ready!")

plt.figure(figsize=(7, 7))
# Plotting the response for each pattern in the iris dataset
plt.pcolor(som.distance_map().T, cmap='bone_r')  # plotting the distance map as background
#plt.colorbar()

target = np.genfromtxt( "../data/transfusion.csv", delimiter=',', usecols=(4))
t = np.zeros(len(target), dtype=int)

# use different colors and markers for each label
markers = ['o', 's', 'D','<','>']
colors = ['C0', 'C1', 'C2','C3', 'C4']
for cnt, xx in enumerate(data):
    w = som.winner(xx)  # getting the winner
    # palce a marker on the winning position for the sample xx
    plt.plot(w[0]+.5, w[1]+.5, markers[t[cnt]], markerfacecolor='None',
             markeredgecolor=colors[t[cnt]], markersize=12, markeredgewidth=2)
plt.axis([0, 7, 0, 7])
plt.savefig('som_iris.png')
plt.show()
# Out:
# Training...
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 2.223997796809728e-05
#  topographic error: 0.19518716577540107
#
# ...ready!

# %% [markdown]
# Activations frequencies
# ----

# %%
plt.figure(figsize=(8, 7))
frequencies = som.activation_response(data)
plt.pcolor(frequencies.T, cmap='Blues') 
plt.colorbar()
plt.show()

# %% [markdown]
# Class pies
# ----

# %%
label = np.genfromtxt( "../data/transfusion.csv", delimiter=',', usecols=(4), dtype=str)
labels_map = som.labels_map(data, label)
label_names = np.unique(label)

plt.figure(figsize=(7, 7))
the_grid = GridSpec(7, 7)
for position in labels_map.keys():
    label_fracs = [labels_map[position][l] for l in label_names]
    plt.subplot(the_grid[6-position[1], position[0]], aspect=1)
    patches, texts = plt.pie(label_fracs)
plt.legend(patches, label_names, bbox_to_anchor=(0, 1.5), ncol=3)
plt.savefig('som_iris_pies.png')
plt.show()

# %% [markdown]
# Quantization error
# ----

# %%
som = MiniSom(7, 7, 4, sigma=3, learning_rate=0.5, 
              neighborhood_function='triangle', random_seed=10)
som.pca_weights_init(data)
max_iter = 10000
q_error = []
t_error = []
iter_x = []
for i in range(max_iter):
    percent = 100*(i+1)/max_iter
    rand_i = np.random.randint(len(data)) # This corresponds to train_random() method.
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
    if (i+1) % 100 == 0:
        q_error.append(som.quantization_error(data))
        t_error.append(som.topographic_error(data))
        iter_x.append(i)
        sys.stdout.write(f'\riteration={i:2d} status={percent:0.2f}%')
        
plt.plot(iter_x, q_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# iteration=9999 status=100.00%
# Text(0.5, 0, 'iteration index')

# %%
plt.plot(iter_x, t_error)
plt.ylabel('quantization error')
plt.xlabel('iteration index')
# Out:
# Text(0.5, 0, 'iteration index')
