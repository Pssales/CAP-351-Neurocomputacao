# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import somoclu
# %matplotlib inline

# %%
df = pd.read_csv('../3-GNG/iris.csv')
# use only two features in order
# to make visualization simpler
data = df[['petal length','petal width','sepal length']].to_numpy()
_ = df['class'].to_numpy()

c1 = np.random.rand(50, 3)/5
c2 = (0.6, 0.1, 0.05) + np.random.rand(50, 3)/5
c3 = (0.4, 0.1, 0.7) + np.random.rand(50, 3)/5
colors = ["red"] * 50
colors.extend(["green"] * 50)
colors.extend(["blue"] * 50)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=colors)
labels = range(150)

# %%
n_rows, n_columns = 100, 160
som = somoclu.Somoclu(n_columns, n_rows, compactsupport=False)
# %time som.train(data)
# Out:
# Warning: data was not float32. A 32-bit copy was made
# Wall time: 1.61 s

# %%
som.view_component_planes()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Camila\\Anaconda3\\envs\\pdi\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
som.view_umatrix(bestmatches=True, bestmatchcolors=colors, labels=labels);

# %%
som.view_umatrix(bestmatches=True, bestmatchcolors=colors, labels=labels,
                 zoom=((50, n_rows), (100, n_columns)));
