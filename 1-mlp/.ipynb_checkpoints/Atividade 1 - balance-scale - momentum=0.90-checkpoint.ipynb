# %% [markdown]
# # <span style="color:#336699">CAP-351 - Neurocomputação
# <hr style="border:1px solid #0077b9;">
#
# Professor:
# - Mascos G. Quiles
#
# Discente:
# - Camila P. Sales

# %% [markdown]
# ## Atividade
#
# - Realizar testes com 3(ou mais) datasets selecionados do repositório da UCI (iris, etc...) para várias configuração da rede
# - Ilustrar graficamente o processo de aprendizagem pela redução do erro quadrático médio
# - Dividir o conjunto em duas partes (Treino e Validação)
# - Entregar um relatório descrevendo os experimentos
#
# ### Considerar
# - Impacto do termo de momentum
# <br>
# - Impacto da regularização L2

# %% [markdown]
# #### Datasets selecionados
#  - Detecção de ocupação https://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+#
#  - Padrão de clientes de cartão de crédito https://archive.ics.uci.edu/ml/machine-learning-databases/00350/
#  - Avila https://archive.ics.uci.edu/ml/datasets/Avila

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Dropout
from livelossplot.keras import PlotLossesCallback
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv( "./data/balance-scale.data", sep="," , header = None);
df.head()
# Out:
#    0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5

# %%
df.columns = ['class',
'Left-Weight',
'Left-Distance',
'Right-Weight',
'Right-Distance']
df.head()
# Out:
#   class  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0     B            1              1             1               1
# 1     R            1              1             1               2
# 2     R            1              1             1               3
# 3     R            1              1             1               4
# 4     R            1              1             1               5

# %%
s = {'L': 0,'B': 1,'R': 2}
df['class'] = df['class'].map(s)

# %%
X = df.drop('class',axis=1)
y = df['class'].to_numpy()

# Dividir os dados em conjuntos de treinamento e teste.
X_train, X_test, y_train, y_test = train_test_split(X, y)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
plot_losses = PlotLossesCallback()

# %%
model = Sequential()

model.add(Dense(64, input_dim=4, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.90, nesterov=True)

model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy','mean_squared_error'
])

history = model.fit(X_train, y_train,
          epochs=200,
          validation_data=(X_test, y_test),
          callbacks=[plot_losses],
          verbose=0)
score = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# Log-loss (cost function):
# training   (min:    0.110, max:    1.065, cur:    0.163)
# validation (min:    0.087, max:    0.719, cur:    0.112)
#
# accuracy:
# training   (min:    0.517, max:    0.964, cur:    0.942)
# validation (min:    0.854, max:    0.987, cur:    0.968)
#
# Mean squared error:
# training   (min:    0.021, max:    0.208, cur:    0.029)
# validation (min:    0.014, max:    0.129, cur:    0.019)
# 157/157 [==============================] - 0s 13us/step

# %%
def loss_plot(history):
    train_acc = history.history['val_loss']
    val_acc = history.history['val_accuracy']

    plt.figure(figsize = (9,5))
    plt.plot(np.arange(1,201), train_acc, marker = 'D', label = 'Loss')
    plt.plot(np.arange(1,201), val_acc, marker = 'o', label = 'Accuracy')

    plt.xlabel('epocas')
    plt.ylabel('acuracia')
    plt.plot('Train/Validation')
    plt.legend()
    plt.margins(0.02)
    plt.show()

# %%
loss_plot(history)
